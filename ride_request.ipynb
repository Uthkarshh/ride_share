# %%
import os
import httpx
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import pandas as pd
from concurrent.futures import ThreadPoolExecutor, as_completed

# %%
# URL of the webpage containing file links
url = "https://www.nyc.gov/site/tlc/about/tlc-trip-record-data.page"

# Folder to save downloaded files
download_folder = "rides"
if not os.path.exists(download_folder):
    os.makedirs(download_folder)

# Function to download a file with session reuse and timeout
def download_file(file_url, folder_path, session):
    file_name = file_url.split("/")[-1]
    file_path = os.path.join(folder_path, file_name)
    
    # Check if file already exists
    if os.path.exists(file_path):
        print(f"{file_name} already exists. Skipping download.")
        return

    # Download the file with a timeout and session reuse
    try:
        response = session.get(file_url, timeout=10.0)  # Timeout set to 10 seconds
        if response.status_code == 200:
            with open(file_path, "wb") as f:
                f.write(response.content)
            print(f"Downloaded {file_name}")
        else:
            print(f"Failed to download {file_name}: {response.status_code}")
    except httpx.RequestError as e:
        print(f"An error occurred while requesting {file_url}: {e}")

# %%
print(os.path.join("rides","fhv_tripdata_2015-01.parquet"))
# Out:
# rides\fhv_tripdata_2015-01.parquet

# %%
# Fetch the page HTML
with httpx.Client(timeout=10.0) as session:  # Timeout for page request
    response = session.get(url)
    soup = BeautifulSoup(response.content, "html.parser")

    # Find all links that match the download pattern
    file_links = []
    for link in soup.find_all("a", href=True):
        href = link["href"]
        if "d37ci6vzurychx.cloudfront.net/trip-data/" in href and href.endswith(".parquet"):
            # Construct the full URL if the href is relative
            file_links.append(urljoin(url, href))

# %%
# Download files concurrently using ThreadPoolExecutor
with httpx.Client() as session:  # Reuse session across threads
    with ThreadPoolExecutor(max_workers=5) as executor:  # Use 5 threads for parallel downloads
        futures = [executor.submit(download_file, file_url, download_folder, session) for file_url in file_links]

        # Wait for all futures to complete
        for future in as_completed(futures):
            future.result()  # Trigger exception handling if download_file raises any exceptions
# Out:
# green_tripdata_2024-02.parquet already exists. Skipping download.fhv_tripdata_2024-03.parquet already exists. Skipping download.
#
# yellow_tripdata_2024-04.parquet already exists. Skipping download.
# green_tripdata_2024-04.parquet already exists. Skipping download.
# fhv_tripdata_2024-04.parquet already exists. Skipping download.
# fhvhv_tripdata_2024-04.parquet already exists. Skipping download.
# green_tripdata_2024-05.parquet already exists. Skipping download.
# fhvhv_tripdata_2024-05.parquet already exists. Skipping download.
# fhv_tripdata_2024-05.parquet already exists. Skipping download.
# yellow_tripdata_2024-06.parquet already exists. Skipping download.
# yellow_tripdata_2024-05.parquet already exists. Skipping download.
# green_tripdata_2024-06.parquet already exists. Skipping download.
# fhvhv_tripdata_2024-06.parquet already exists. Skipping download.
# green_tripdata_2024-07.parquet already exists. Skipping download.
# fhvhv_tripdata_2024-07.parquet already exists. Skipping download.
# fhv_tripdata_2024-06.parquet already exists. Skipping download.
# green_tripdata_2024-08.parquet already exists. Skipping download.
# fhv_tripdata_2024-07.parquet already exists. Skipping download.
# yellow_tripdata_2024-07.parquet already exists. Skipping download.
# yellow_tripdata_2024-08.parquet already exists. Skipping download.
# Downloaded green_tripdata_2023-01.parquet
# Downloaded yellow_tripdata_2023-01.parquet
# Downloaded yellow_tripdata_2023-02.parquet
# Downloaded green_tripdata_2023-02.parquet
# Downloaded fhv_tripdata_2023-01.parquet
# Downloaded fhv_tripdata_2024-08.parquet
# Downloaded fhv_tripdata_2023-02.parquet
# Downloaded yellow_tripdata_2023-04.parquet
# Downloaded green_tripdata_2023-04.parquet
# Downloaded yellow_tripdata_2023-03.parquet
# Downloaded fhv_tripdata_2023-04.parquet
# Downloaded yellow_tripdata_2023-06.parquet
# Downloaded green_tripdata_2023-06.parquet
# Downloaded fhv_tripdata_2023-06.parquet
# Downloaded fhvhv_tripdata_2023-02.parquet
# Downloaded fhvhv_tripdata_2024-08.parquet
# Downloaded green_tripdata_2023-12.parquet
# Downloaded yellow_tripdata_2023-12.parquet
# Downloaded green_tripdata_2022-01.parquet
# Downloaded fhv_tripdata_2022-01.parquet
# Downloaded fhvhv_tripdata_2023-01.parquet
# Downloaded yellow_tripdata_2022-01.parquet
# Downloaded green_tripdata_2022-02.parquet
# Downloaded fhv_tripdata_2022-02.parquet
# Downloaded fhvhv_tripdata_2023-06.parquet
# Downloaded fhvhv_tripdata_2023-04.parquet
# Downloaded green_tripdata_2022-03.parquet
# Downloaded fhv_tripdata_2022-03.parquet
# Downloaded yellow_tripdata_2022-02.parquet
# Downloaded yellow_tripdata_2022-03.parquet
# Downloaded green_tripdata_2022-04.parquet
# Downloaded fhv_tripdata_2022-04.parquet
# Downloaded yellow_tripdata_2022-04.parquet
# Downloaded yellow_tripdata_2022-05.parquet
# Downloaded green_tripdata_2022-05.parquet
# Downloaded fhv_tripdata_2022-05.parquet
# Downloaded fhvhv_tripdata_2022-01.parquet
# Downloaded yellow_tripdata_2022-06.parquet
# Downloaded green_tripdata_2022-06.parquet
# Downloaded fhv_tripdata_2022-06.parquet
# Downloaded fhvhv_tripdata_2022-03.parquet
# Downloaded fhvhv_tripdata_2022-02.parquet
# Downloaded green_tripdata_2022-07.parquet
# Downloaded fhv_tripdata_2022-07.parquet
# Downloaded yellow_tripdata_2022-07.parquet
# Downloaded fhvhv_tripdata_2022-04.parquet
# Downloaded green_tripdata_2022-08.parquet
# Downloaded fhv_tripdata_2022-08.parquet
# Downloaded fhvhv_tripdata_2022-05.parquet
# Downloaded fhvhv_tripdata_2022-06.parquet
# Downloaded green_tripdata_2022-09.parquet
# Downloaded yellow_tripdata_2022-09.parquet
# Downloaded yellow_tripdata_2022-08.parquet
# Downloaded fhv_tripdata_2022-09.parquet
# Downloaded green_tripdata_2022-10.parquet
# Downloaded fhv_tripdata_2022-10.parquet
# Downloaded yellow_tripdata_2022-10.parquet
# Downloaded yellow_tripdata_2022-11.parquet
# Downloaded green_tripdata_2022-11.parquet
# Downloaded fhv_tripdata_2022-11.parquet
# Downloaded fhvhv_tripdata_2022-09.parquet
# Downloaded yellow_tripdata_2022-12.parquet
# Downloaded green_tripdata_2022-12.parquet
# Downloaded fhv_tripdata_2022-12.parquet
# Downloaded fhvhv_tripdata_2022-07.parquet
# Downloaded fhvhv_tripdata_2022-10.parquet
# Downloaded yellow_tripdata_2021-01.parquet
# Downloaded green_tripdata_2021-01.parquet
# Downloaded fhv_tripdata_2021-01.parquet
# Downloaded yellow_tripdata_2021-02.parquet
# Downloaded green_tripdata_2021-02.parquet
# Downloaded fhv_tripdata_2021-02.parquet
# Downloaded fhvhv_tripdata_2022-11.parquet
# Downloaded fhvhv_tripdata_2022-08.parquet
# Downloaded green_tripdata_2021-03.parquet
# Downloaded fhv_tripdata_2021-03.parquet
# Downloaded yellow_tripdata_2021-03.parquet
# Downloaded yellow_tripdata_2021-04.parquet
# Downloaded green_tripdata_2021-04.parquet
# Downloaded fhvhv_tripdata_2021-02.parquet
# Downloaded fhvhv_tripdata_2021-01.parquet
# Downloaded fhv_tripdata_2021-04.parquet
# Downloaded green_tripdata_2021-05.parquet
# Downloaded fhv_tripdata_2021-05.parquet
# Downloaded fhvhv_tripdata_2022-12.parquet
# Downloaded yellow_tripdata_2021-05.parquet
# Downloaded green_tripdata_2021-06.parquet
# Downloaded yellow_tripdata_2021-06.parquet
# Downloaded fhv_tripdata_2021-06.parquet
# Downloaded yellow_tripdata_2021-07.parquet
# Downloaded green_tripdata_2021-07.parquet
# Downloaded fhv_tripdata_2021-07.parquet
# Downloaded fhvhv_tripdata_2021-03.parquet
# Downloaded yellow_tripdata_2021-08.parquet
# Downloaded green_tripdata_2021-08.parquet
# Downloaded fhv_tripdata_2021-08.parquet
# Downloaded fhvhv_tripdata_2021-06.parquet
# Downloaded yellow_tripdata_2021-09.parquet
# Downloaded green_tripdata_2021-09.parquet
# Downloaded fhv_tripdata_2021-09.parquet
# Downloaded fhvhv_tripdata_2021-07.parquet
# Downloaded fhvhv_tripdata_2021-05.parquet
# Downloaded green_tripdata_2021-10.parquet
# Downloaded yellow_tripdata_2021-10.parquet
# Downloaded fhv_tripdata_2021-10.parquet
# Downloaded yellow_tripdata_2021-11.parquet
# Downloaded green_tripdata_2021-11.parquet
# Downloaded fhv_tripdata_2021-11.parquet
# Downloaded fhvhv_tripdata_2021-08.parquet
# Downloaded fhvhv_tripdata_2021-09.parquet
# Downloaded green_tripdata_2021-12.parquet
# An error occurred while requesting https://d37ci6vzurychx.cloudfront.net/trip-data/fhvhv_tripdata_2021-04.parquet: peer closed connection without sending complete message body (received 347589263 bytes, expected 368416040)
# An error occurred while requesting https://d37ci6vzurychx.cloudfront.net/trip-data/fhvhv_tripdata_2021-11.parquet: peer closed connection without sending complete message body (received 46088464 bytes, expected 411061458)
# Downloaded fhvhv_tripdata_2021-10.parquet
# Downloaded fhv_tripdata_2021-12.parquet
# Downloaded green_tripdata_2020-01.parquet
# Downloaded yellow_tripdata_2021-12.parquet
# Downloaded fhv_tripdata_2020-01.parquet
# Downloaded green_tripdata_2020-02.parquet
# Downloaded fhv_tripdata_2020-02.parquet
# Downloaded yellow_tripdata_2020-02.parquet
# Downloaded yellow_tripdata_2020-03.parquet
# Downloaded yellow_tripdata_2020-01.parquet
# Downloaded green_tripdata_2020-03.parquet
# Downloaded fhv_tripdata_2020-03.parquet
# Downloaded yellow_tripdata_2020-04.parquet
# Downloaded green_tripdata_2020-04.parquet
# Downloaded fhv_tripdata_2020-04.parquet
# Downloaded fhvhv_tripdata_2021-12.parquet
# Downloaded yellow_tripdata_2020-05.parquet
# Downloaded green_tripdata_2020-05.parquet
# Downloaded fhv_tripdata_2020-05.parquet
# Downloaded fhvhv_tripdata_2020-04.parquet
# Downloaded yellow_tripdata_2020-06.parquet
# Downloaded green_tripdata_2020-06.parquet
# Downloaded fhv_tripdata_2020-06.parquet
# Downloaded fhvhv_tripdata_2020-05.parquet
# Downloaded fhvhv_tripdata_2020-03.parquet
# Downloaded yellow_tripdata_2020-07.parquet
# Downloaded green_tripdata_2020-07.parquet
# Downloaded fhv_tripdata_2020-07.parquet
# Downloaded yellow_tripdata_2020-08.parquet
# Downloaded green_tripdata_2020-08.parquet
# Downloaded fhvhv_tripdata_2020-01.parquet
# Downloaded fhv_tripdata_2020-08.parquet
# Downloaded yellow_tripdata_2020-09.parquet
# Downloaded green_tripdata_2020-09.parquet
# Downloaded fhvhv_tripdata_2020-06.parquet
# Downloaded fhv_tripdata_2020-09.parquet
# Downloaded fhvhv_tripdata_2020-02.parquet
# Downloaded green_tripdata_2020-10.parquet
# Downloaded yellow_tripdata_2020-10.parquet
# Downloaded fhv_tripdata_2020-10.parquet
# Downloaded yellow_tripdata_2020-11.parquet
# Downloaded green_tripdata_2020-11.parquet
# Downloaded fhv_tripdata_2020-11.parquet
# Downloaded fhvhv_tripdata_2020-08.parquet
# Downloaded yellow_tripdata_2020-12.parquet
# Downloaded green_tripdata_2020-12.parquet
# Downloaded fhv_tripdata_2020-12.parquet
# Downloaded fhvhv_tripdata_2020-09.parquet
# Downloaded yellow_tripdata_2019-01.parquet
# Downloaded green_tripdata_2019-01.parquet
# Downloaded fhvhv_tripdata_2020-07.parquet
# Downloaded fhvhv_tripdata_2020-12.parquet
# Downloaded green_tripdata_2019-02.parquet
# Downloaded fhv_tripdata_2019-02.parquet
# Downloaded fhvhv_tripdata_2020-11.parquet
# Downloaded yellow_tripdata_2019-02.parquet
# Downloaded fhvhv_tripdata_2020-10.parquet
# Downloaded green_tripdata_2019-03.parquet
# Downloaded fhv_tripdata_2019-03.parquet
# Downloaded fhv_tripdata_2019-01.parquet
# Downloaded green_tripdata_2019-04.parquet
# Downloaded yellow_tripdata_2019-03.parquet
# Downloaded yellow_tripdata_2019-04.parquet
# Downloaded fhv_tripdata_2019-04.parquet
# Downloaded green_tripdata_2019-05.parquet
# Downloaded yellow_tripdata_2019-05.parquet
# Downloaded fhv_tripdata_2019-05.parquet
# Downloaded yellow_tripdata_2019-06.parquet
# Downloaded green_tripdata_2019-06.parquet
# Downloaded fhv_tripdata_2019-06.parquet
# Downloaded fhvhv_tripdata_2019-02.parquet
# Downloaded yellow_tripdata_2019-07.parquet
# Downloaded green_tripdata_2019-07.parquet
# Downloaded fhv_tripdata_2019-07.parquet
# Downloaded fhvhv_tripdata_2019-04.parquet
# Downloaded fhvhv_tripdata_2019-03.parquet
# Downloaded fhvhv_tripdata_2019-05.parquet
# Downloaded green_tripdata_2019-08.parquet
# Downloaded fhv_tripdata_2019-08.parquet
# Downloaded fhvhv_tripdata_2019-07.parquet
# Downloaded yellow_tripdata_2019-08.parquet
# Downloaded fhv_tripdata_2019-09.parquet
# Downloaded green_tripdata_2019-09.parquet
# Downloaded yellow_tripdata_2019-09.parquet
# Downloaded green_tripdata_2019-10.parquet
# Downloaded fhv_tripdata_2019-10.parquet
# Downloaded yellow_tripdata_2019-10.parquet
# Downloaded fhvhv_tripdata_2019-06.parquet
# Downloaded green_tripdata_2019-11.parquet
# Downloaded fhvhv_tripdata_2019-08.parquet
# Downloaded fhv_tripdata_2019-11.parquet
# Downloaded yellow_tripdata_2019-11.parquet
# Downloaded fhvhv_tripdata_2019-09.parquet
# Downloaded green_tripdata_2019-12.parquet
# Downloaded fhv_tripdata_2019-12.parquet
# Downloaded yellow_tripdata_2019-12.parquet
# Downloaded green_tripdata_2018-01.parquet
# Downloaded fhv_tripdata_2018-01.parquet
# Downloaded yellow_tripdata_2018-01.parquet
# Downloaded green_tripdata_2018-02.parquet
# Downloaded yellow_tripdata_2018-02.parquet
# Downloaded fhv_tripdata_2018-02.parquet
# Downloaded green_tripdata_2018-03.parquet
# Downloaded fhvhv_tripdata_2019-10.parquet
# Downloaded yellow_tripdata_2018-03.parquet
# Downloaded green_tripdata_2018-04.parquet
# Downloaded fhv_tripdata_2018-03.parquet
# Downloaded yellow_tripdata_2018-04.parquet
# Downloaded green_tripdata_2018-05.parquet
# Downloaded yellow_tripdata_2018-05.parquet
# Downloaded fhvhv_tripdata_2019-12.parquet
# Downloaded green_tripdata_2018-06.parquet
# Downloaded fhv_tripdata_2018-04.parquet
# Downloaded fhvhv_tripdata_2019-11.parquet
# Downloaded fhv_tripdata_2018-05.parquet
# Downloaded green_tripdata_2018-07.parquet
# Downloaded yellow_tripdata_2018-06.parquet
# Downloaded green_tripdata_2018-08.parquet
# Downloaded yellow_tripdata_2018-07.parquet
# Downloaded yellow_tripdata_2018-08.parquet
# Downloaded green_tripdata_2018-09.parquet
# Downloaded fhv_tripdata_2018-07.parquet
# Downloaded yellow_tripdata_2018-09.parquet
# Downloaded green_tripdata_2018-10.parquet
# Downloaded yellow_tripdata_2018-10.parquet
# Downloaded fhv_tripdata_2018-09.parquet
# Downloaded green_tripdata_2018-11.parquet
# Downloaded fhv_tripdata_2018-10.parquet
# Downloaded yellow_tripdata_2018-11.parquet
# Downloaded green_tripdata_2018-12.parquet
# Downloaded yellow_tripdata_2018-12.parquet
# Downloaded fhv_tripdata_2018-06.parquet
# Downloaded fhv_tripdata_2018-08.parquet
# Downloaded fhv_tripdata_2018-11.parquet
# Downloaded green_tripdata_2017-01.parquet
# Downloaded yellow_tripdata_2017-01.parquet
# Downloaded green_tripdata_2017-02.parquet
# Downloaded fhv_tripdata_2017-02.parquet
# Downloaded green_tripdata_2017-03.parquet
# Downloaded fhv_tripdata_2018-12.parquet
# Downloaded fhv_tripdata_2017-01.parquet
# Downloaded fhv_tripdata_2017-03.parquet
# Downloaded green_tripdata_2017-04.parquet
# Downloaded yellow_tripdata_2017-02.parquet
# Downloaded green_tripdata_2017-05.parquet
# Downloaded fhv_tripdata_2017-05.parquet
# Downloaded yellow_tripdata_2017-03.parquet
# Downloaded yellow_tripdata_2017-04.parquet
# Downloaded fhv_tripdata_2017-04.parquet
# Downloaded green_tripdata_2017-06.parquet
# Downloaded green_tripdata_2017-07.parquet
# Downloaded yellow_tripdata_2017-05.parquet
# Downloaded yellow_tripdata_2017-06.parquet
# Downloaded green_tripdata_2017-08.parquet
# Downloaded fhv_tripdata_2017-06.parquet
# Downloaded yellow_tripdata_2017-07.parquet
# Downloaded green_tripdata_2017-09.parquet
# Downloaded yellow_tripdata_2017-08.parquet
# Downloaded fhv_tripdata_2017-08.parquet
# Downloaded fhv_tripdata_2017-07.parquet
# Downloaded yellow_tripdata_2017-09.parquet
# Downloaded green_tripdata_2017-10.parquet
# Downloaded green_tripdata_2017-11.parquet
# Downloaded yellow_tripdata_2017-10.parquet
# Downloaded fhv_tripdata_2017-10.parquet
# Downloaded yellow_tripdata_2017-12.parquet
# Downloaded yellow_tripdata_2017-11.parquet
# Downloaded green_tripdata_2017-12.parquet
# Downloaded fhv_tripdata_2017-09.parquet
# Downloaded green_tripdata_2016-01.parquet
# Downloaded fhv_tripdata_2016-01.parquet
# Downloaded green_tripdata_2016-02.parquet
# Downloaded yellow_tripdata_2016-01.parquet
# Downloaded fhv_tripdata_2017-12.parquetDownloaded fhv_tripdata_2017-11.parquet
#
# Downloaded fhv_tripdata_2016-02.parquet
# Downloaded green_tripdata_2016-03.parquet
# Downloaded yellow_tripdata_2016-02.parquet
# Downloaded fhv_tripdata_2016-03.parquet
# Downloaded fhv_tripdata_2016-04.parquet
# Downloaded green_tripdata_2016-04.parquet
# Downloaded green_tripdata_2016-05.parquet
# Downloaded fhv_tripdata_2016-05.parquet
# Downloaded green_tripdata_2016-06.parquet
# Downloaded yellow_tripdata_2016-03.parquet
# Downloaded yellow_tripdata_2016-05.parquet
# Downloaded fhv_tripdata_2016-06.parquet
# Downloaded green_tripdata_2016-07.parquet
# Downloaded fhv_tripdata_2016-07.parquet
# Downloaded yellow_tripdata_2016-06.parquet
# Downloaded green_tripdata_2016-08.parquet
# Downloaded fhv_tripdata_2016-08.parquet
# Downloaded green_tripdata_2016-09.parquet
# Downloaded yellow_tripdata_2016-08.parquet
# Downloaded yellow_tripdata_2016-09.parquet
# Downloaded fhv_tripdata_2016-09.parquet
# Downloaded green_tripdata_2016-10.parquet
# Downloaded yellow_tripdata_2016-04.parquet
# Downloaded yellow_tripdata_2016-07.parquet
# Downloaded green_tripdata_2016-11.parquet
# Downloaded fhv_tripdata_2016-10.parquet
# Downloaded fhv_tripdata_2016-11.parquet
# Downloaded green_tripdata_2016-12.parquet
# Downloaded yellow_tripdata_2016-10.parquet
# Downloaded yellow_tripdata_2016-11.parquet
# Downloaded green_tripdata_2015-01.parquet
# Downloaded fhv_tripdata_2015-01.parquet
# Downloaded green_tripdata_2015-02.parquet
# Downloaded fhv_tripdata_2015-02.parquet
# Downloaded fhv_tripdata_2016-12.parquet
# Downloaded yellow_tripdata_2015-01.parquet
# Downloaded fhv_tripdata_2015-03.parquet
# Downloaded yellow_tripdata_2016-12.parquet
# Downloaded green_tripdata_2015-03.parquet
# Downloaded fhv_tripdata_2015-04.parquet
# Downloaded green_tripdata_2015-04.parquet
# Downloaded green_tripdata_2015-05.parquet
# Downloaded yellow_tripdata_2015-03.parquet
# Downloaded fhv_tripdata_2015-05.parquet
# Downloaded green_tripdata_2015-06.parquet
# Downloaded fhv_tripdata_2015-06.parquet
# Downloaded yellow_tripdata_2015-04.parquet
# Downloaded yellow_tripdata_2015-05.parquet
# Downloaded fhv_tripdata_2015-07.parquet
# Downloaded yellow_tripdata_2015-06.parquet
# Downloaded yellow_tripdata_2015-02.parquet
# Downloaded green_tripdata_2015-07.parquet
# Downloaded green_tripdata_2015-08.parquet
# Downloaded green_tripdata_2015-09.parquet
# Downloaded fhv_tripdata_2015-08.parquet
# Downloaded fhv_tripdata_2015-09.parquet
# Downloaded green_tripdata_2015-10.parquet
# Downloaded fhv_tripdata_2015-10.parquet
# Downloaded yellow_tripdata_2015-11.parquet
# Downloaded yellow_tripdata_2015-09.parquet
# Downloaded green_tripdata_2015-11.parquet
# Downloaded fhv_tripdata_2015-11.parquet
# Downloaded green_tripdata_2015-12.parquet
# Downloaded yellow_tripdata_2015-08.parquet
# Downloaded fhv_tripdata_2015-12.parquet
# Downloaded green_tripdata_2014-01.parquet
# Downloaded yellow_tripdata_2015-07.parquet
# Downloaded green_tripdata_2014-02.parquet
# Downloaded yellow_tripdata_2015-10.parquet
# Downloaded yellow_tripdata_2014-02.parquet
# Downloaded green_tripdata_2014-03.parquet
# Downloaded green_tripdata_2014-04.parquet
# Downloaded yellow_tripdata_2015-12.parquet
# Downloaded green_tripdata_2014-05.parquet
# Downloaded yellow_tripdata_2014-04.parquet
# Downloaded green_tripdata_2014-06.parquet
# Downloaded yellow_tripdata_2014-01.parquet
# Downloaded yellow_tripdata_2014-03.parquet
# Downloaded green_tripdata_2014-07.parquet
# Downloaded green_tripdata_2014-08.parquet
# Downloaded yellow_tripdata_2014-05.parquet
# Downloaded green_tripdata_2014-09.parquet
# Downloaded yellow_tripdata_2014-06.parquet
# Downloaded green_tripdata_2014-10.parquet
# Downloaded yellow_tripdata_2014-09.parquet
# Downloaded green_tripdata_2014-11.parquet
# Downloaded yellow_tripdata_2014-07.parquet
# Downloaded yellow_tripdata_2014-11.parquet
# Downloaded green_tripdata_2014-12.parquet
# Downloaded yellow_tripdata_2014-10.parquet
# Downloaded yellow_tripdata_2014-08.parquet
# Downloaded yellow_tripdata_2014-12.parquet
# Downloaded yellow_tripdata_2013-01.parquet
# Downloaded yellow_tripdata_2013-05.parquet
# Downloaded yellow_tripdata_2013-02.parquet
# Downloaded yellow_tripdata_2013-03.parquet
# Failed to download green_tripdata_2013-08.parquet: 403
# Downloaded yellow_tripdata_2013-07.parquet
# Failed to download green_tripdata_2013-09.parquet: 403
# Downloaded yellow_tripdata_2013-06.parquet
# Failed to download green_tripdata_2013-10.parquet: 403
# Downloaded yellow_tripdata_2013-04.parquet
# Failed to download green_tripdata_2013-11.parquet: 403
# Downloaded yellow_tripdata_2013-10.parquet
# Failed to download green_tripdata_2013-12.parquet: 403
# Downloaded yellow_tripdata_2012-01.parquet
# Downloaded yellow_tripdata_2013-08.parquet
# Downloaded yellow_tripdata_2013-11.parquet
# Downloaded yellow_tripdata_2013-12.parquet
# Downloaded yellow_tripdata_2013-09.parquet
# Downloaded yellow_tripdata_2012-02.parquet
# Downloaded yellow_tripdata_2012-03.parquet
# Downloaded yellow_tripdata_2012-05.parquet
# Downloaded yellow_tripdata_2012-08.parquet
# Downloaded yellow_tripdata_2012-07.parquet
# Downloaded yellow_tripdata_2012-06.parquet
# Downloaded yellow_tripdata_2012-04.parquet
# Downloaded yellow_tripdata_2012-11.parquet
# Downloaded yellow_tripdata_2012-09.parquet
# Downloaded yellow_tripdata_2012-10.parquet
# Downloaded yellow_tripdata_2012-12.parquet
# Downloaded yellow_tripdata_2011-02.parquet
# Downloaded yellow_tripdata_2011-03.parquet
# Downloaded yellow_tripdata_2011-04.parquet
# Downloaded yellow_tripdata_2011-01.parquet
# Downloaded yellow_tripdata_2011-07.parquet
# Downloaded yellow_tripdata_2011-05.parquet
# Downloaded yellow_tripdata_2011-06.parquet
# Downloaded yellow_tripdata_2011-08.parquet
# Downloaded yellow_tripdata_2011-09.parquet
# Downloaded yellow_tripdata_2011-12.parquet
# Downloaded yellow_tripdata_2011-11.parquet
# Downloaded yellow_tripdata_2011-10.parquet
# Downloaded yellow_tripdata_2010-02.parquet
# Downloaded yellow_tripdata_2010-01.parquet
# Downloaded yellow_tripdata_2010-05.parquet
# Downloaded yellow_tripdata_2010-04.parquet
# Downloaded yellow_tripdata_2010-03.parquet
# Downloaded yellow_tripdata_2010-06.parquet
# Downloaded yellow_tripdata_2010-07.parquet
# Downloaded yellow_tripdata_2010-10.parquet
# Downloaded yellow_tripdata_2010-09.parquet
# Downloaded yellow_tripdata_2010-08.parquet
# Downloaded yellow_tripdata_2010-11.parquet
# Downloaded yellow_tripdata_2010-12.parquet
# Downloaded yellow_tripdata_2009-01.parquet
# Downloaded yellow_tripdata_2009-03.parquet
# Downloaded yellow_tripdata_2009-02.parquet
# Downloaded yellow_tripdata_2009-05.parquet
# Downloaded yellow_tripdata_2009-06.parquet
# Downloaded yellow_tripdata_2009-04.parquet
# Downloaded yellow_tripdata_2009-08.parquet
# Downloaded yellow_tripdata_2009-07.parquet
# Downloaded yellow_tripdata_2009-11.parquet
# Downloaded yellow_tripdata_2009-09.parquet
# Downloaded yellow_tripdata_2009-10.parquet
# Downloaded yellow_tripdata_2009-12.parquet
